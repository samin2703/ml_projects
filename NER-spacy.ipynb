# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
from bs4 import BeautifulSoup
import requests
import re

# Load English language model
nlp = en_core_web_sm.load()

# Process a text document
doc = nlp('''Hello! My name is Aurin and I live in Dhaka. 
          I study "Robotics and Mechatronics 
          Engineering" at University of Dhaka
          which was established
          on 15th May, 2015. Currently, I work as a Teacher and earn about $8000/month''')

# %%
# Print entities with their IOB (Inside, Outside, Beginning) and entity type
print([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(Hello, 'O', ''), (!, 'O', ''), (My, 'O', ''), (name, 'O', ''), (is, 'O', ''), (Aurin, 'B', 'PERSON'), (and, 'O', ''), (I, 'O', ''), (live, 'O', ''), (in, 'O', ''), (Dhaka, 'B', 'GPE'), (., 'O', ''), (
#           , 'O', ''), (I, 'O', ''), (study, 'O', ''), (", 'O', ''), (Robotics, 'B', 'WORK_OF_ART'), (and, 'I', 'WORK_OF_ART'), (Mechatronics, 'I', 'WORK_OF_ART'), (
#           , 'I', 'WORK_OF_ART'), (Engineering, 'I', 'WORK_OF_ART'), (", 'O', ''), (at, 'O', ''), (University, 'B', 'ORG'), (of, 'I', 'ORG'), (Dhaka, 'I', 'ORG'), (
#           , 'O', ''), (which, 'O', ''), (was, 'O', ''), (established, 'O', ''), (
#           , 'O', ''), (on, 'O', ''), (15th, 'B', 'DATE'), (May, 'I', 'DATE'), (,, 'I', 'DATE'), (2015, 'I', 'DATE'), (., 'O', ''), (Currently, 'O', ''), (,, 'O', ''), (I, 'O', ''), (work, 'O', ''), (as, 'O', ''), (a, 'O', ''), (Teacher, 'O', ''), (and, 'O', ''), (earn, 'O', ''), (about, 'B', 'MONEY'), ($, 'I', 'MONEY'), (8000, 'I', 'MONEY'), (/, 'I', 'MONEY'), (month, 'I', 'MONEY')]

# %%
# Visualize named entities in the document
displacy.render(nlp(str(doc)), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Hello! My name is
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aurin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and I live in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dhaka
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . <br>          I study &quot;
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Robotics and Mechatronics
#           Engineering
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# &quot; at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     University of Dhaka
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# <br>          which was established<br>          on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15th May, 2015
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Currently, I work as a Teacher and earn
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about $8000/month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </div></span>

# %%
# Visualize syntactic dependencies in the document
displacy.render(nlp(str(doc)), jupyter=True, style='dep', options={'distance': 120})

# Sentences written in a certain way make a Huge Impact

# Two example sentences for NER analysis
sentence1 = "Alice Walker has booked a flight for December 10th, 2023, to travel from Dhaka to Cox's Bazar and experience the stunning coastal beauty."
sentence2 = "In her travel itinerary, Alice Walker is set to journey from Dhaka to Cox's Bazar on December 10th, 2023, immersing herself in the scenic wonders of the coastline."

# Process the sentences with NLP pipeline
doc1 = nlp(sentence1)
doc2 = nlp(sentence2)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b14a03302e9845b3acb3bd11ad20d53e-0" class="displacy" width="5210" height="377.0" direction="ltr" style="max-width: none; height: 377.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Hello!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">My</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">name</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">Aurin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">live</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">Dhaka.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">
#           </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">study &quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">Robotics</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">Mechatronics</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">
#           </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">Engineering&quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">University</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">Dhaka</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">
#           </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">which</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">established</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">
#           </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">15th</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="3530">May,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">2015.</tspan>
#     <tspan cl

# %%
# Visualize named entities in the sentences
displacy.render(doc1, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alice Walker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has booked a flight for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     December 10th, 2023
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , to travel from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dhaka
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cox's Bazar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and experience the stunning coastal beauty.</div></span>

# %%
displacy.render(doc2, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# %%
# Count the occurrences of different entity labels in the document
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'CARDINAL': 51,
#          'ORG': 30,
#          'GPE': 29,
#          'PERSON': 19,
#          'DATE': 17,
#          'LOC': 8,
#          'TIME': 8,
#          'NORP': 4,
#          'ORDINAL': 3,
#          'WORK_OF_ART': 2,
#          'EVENT': 2,
#          'PERCENT': 1,
#          'FAC': 1,
#          'PRODUCT': 1})

# %%
# Get the three most common entity items and their occurrences
items = [x.text for x in article.ents]
Counter(items).most_common(3)
# Out:
# [('UConn', 12), ('Huskies', 6), ('80-75', 5)]

# %%
# Display the 30th sentence in the document
sentences = [x for x in article.sents]
print(sentences[30])
# Out:
# View this post on Instagram            A post shared by UConn Men's Basketball (@uconnmbb)

# %%
# Visualize syntactic dependencies in the 30th sentence
displacy.render(nlp(str(sentences[30])), jupyter=True, style='dep', options={'distance': 70})

# Extract relevant information from the 30th sentence, excluding stop words and punctuation
[(x, x.pos_, x.lemma_, x.ent_type_) for x in [y
                                            for y
                                            in nlp(str(sentences[30]))
                                            if not y.is_stop and y.pos_ != 'PUNCT']]

# Print entities and their labels in the 25th sentence
dict([(str(x), x.label_) for x in nlp(str(sentences[25])).ents])
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3d6d3003265845b2a610aa299780192e-0" class="displacy" width="1170" height="242.0" direction="ltr" style="max-width: none; height: 242.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="152.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">View</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="152.0">
#     <tspan class="displacy-word" fill="currentColor" x="120">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="120">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="152.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">post</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="152.0">
#     <tspan class="displacy-word" fill="currentColor" x="260">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="260">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="152.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">Instagram</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="152.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">           </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="152.0">
#     <tspan class="displacy-word" fill="currentColor" x="470">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="470">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="152.0">
#     <tspan class="displacy-word" fill="currentColor" x="540">post</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="540">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="152.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">shared</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="152.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="152.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">UConn</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="152.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">Men</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="152.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="152.0">
#     <tspan class="displacy-word" fill="currentColor" x="960">Basketball (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="960">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="152.0">
#     <tspan class="displacy-word" fill="currentColor" x="1030">@uconnmbb)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1030">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="152.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">SPACE</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3d6d3003265845b2a610aa299780192e-0-0" stroke-width="2px" d="M140,107.0 C140,72.0 180.0,72.0 180.0,107.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3d6d3003265845b2a610aa299780192e-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M140,109.0 L132,97.0 148,97.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3d6d3003265845b2a610aa299780192e-0-1" stroke-width="2px" d="M70,107.0 C70,37.0 185.0,37.0 185.0,107.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3d6d3003265845b2a610aa299780192e-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M185.0,109.0 L193.0,97.0 177.0,97.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3d6d3003265845b2a610aa299780192e-0-2" stroke-width="2px" d="M70,107.0 C70,2.0 260.0,2.0 260.0,107.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3d6d3003265845b2a610aa299780192e-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M260.0,109.0 L268.0,97.0 252.0,97.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3d6d3003265845b2a610aa299780192e-0-3" stroke-width="2px" d="M350,107.0 C350,37.0 535.0,37.0 535.0,107.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3d6d3003265845b2a610aa299780192e-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M350,109.0 L342,97.0 358,97.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3d6d3003265845b2a610aa299780192e-0-4" stroke-width="2px" d="M350,107.0 C350,72.0 390.0,72.0 390.0,107.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3d6d3003265845b2a610aa299780192e-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M390.0,109.0 L398.0,97.0 382.0,97.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3d6d3003265845b2a610aa299780192e-0-5" stroke-width="2px" d="M490,107.0 C490,72.0 530.0,72.0 530.0,107.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3d6d3003265845b2a610aa299780192e-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M490,109.0 L482,97.0 498,97.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3d6d3003265845b2a610aa299780192e-0-6" stroke-width="2px" d="M280,107.0 C280,2.0 540.0,2.0 540.0,107.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-siz
# {'first-half': 'DATE',
#  'Karaban': 'ORG',
#  'the second half': 'DATE',
#  'Tristen Newton': 'ORG'}
